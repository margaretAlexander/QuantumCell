# %%
# clean single cell data
# keeping this as a notebook since you need to see umi distribution to determine thresholds

import anndata as ad             # For reading/writing AnnData files
import matplotlib.pyplot as plt  # For plotting
import metacells as mc           # The Metacells package
import numpy as np               # For array/matrix operations
import pandas as pd              # For data frames
import os                        # For filesystem operations
import seaborn as sb             # For plotting
import scipy.sparse as sp        # For sparse matrices
import shutil                    # for filesystem operations
from math import hypot           # For plotting
from typing import *
import scanpy as sc
# Out:
# /mnt/scratch1/miniconda3/envs/metacell_MA/lib/python3.14/site-packages/google_crc32c/__init__.py:29: RuntimeWarning: As the c extension couldn't be imported, `google-crc32c` is using a pure python implementation that is significantly slower. If possible, please configure a c build environment and compile the extension
#   warnings.warn(_SLOW_CRC32C_WARNING, RuntimeWarning)

# %%
# constants
dataset_name = 'retina'
OUTPUT_DIR = 'metacell_clean/'
dataset_dir = 'cellxgene/'


# genes to explicitly exclude
EXCLUDED_GENE_NAMES = ['XIST', 'MALAT1']  # Sex-specific genes.
EXCLUDED_GENE_PATTERNS = ['MT-.*']        # Mitochondrial.

# %%
# %%time
full = ad.read_h5ad(dataset_dir + dataset_name + '.h5ad')
full
# Out:
# CPU times: user 1min 12s, sys: 6.12 s, total: 1min 18s
# Wall time: 1min 59s
# AnnData object with n_obs × n_vars = 748679 × 21588
#     obs: 'Sample', 'Study', 'Translocations', 'Cytogenetics', 'Mutations', 'ELN Classification', 'ELN Risk Group', 'Main Age Group', 'Fine Age Group', 'HSPC Cell Type', 'age_floor', 'development_stage_ontology_term_id', 'donor_id', 'sex_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'disease_ontology_term_id', 'tissue_type', 'tissue_ontology_term_id', 'suspension_type', 'cell_type_ontology_term_id', 'assay_ontology_term_id', 'is_primary_data', 'Author Cell Type', 'cell_type', 'assay', 'disease', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'gene_symbol', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type'
#     uns: 'Author Cell Type_colors', 'batch_condition', 'citation', 'default_embedding', 'organism', 'organism_ontology_term_id', 'schema_reference', 'schema_version', 'title'
#     obsm: 'X_pca', 'X_scVI_umap', 'X_uncorrected_umap'

# %%
# make sure data is float32 (metacell requires this)
full.X = full.X.astype(np.float32)

# %%
# check disease names
full.obs['disease']
# Out:
# AML508084-AAACCTGAGAAACGCC-1    myeloid leukemia
# AML508084-AAACCTGAGAGTGAGA-1    myeloid leukemia
# AML508084-AAACCTGAGTCGATAA-1    myeloid leukemia
# AML508084-AAACCTGAGTGCGTGA-1    myeloid leukemia
# AML508084-AAACCTGCACCACCAG-1    myeloid leukemia
#                                       ...
# PBMMC3-TTTGTCACAATGAAAC-1                 normal
# PBMMC3-TTTGTCACATCTGGTA-1                 normal
# PBMMC3-TTTGTCAGTACAGCAG-1                 normal
# PBMMC3-TTTGTCAGTGTGAATA-1                 normal
# PBMMC3-TTTGTCAGTTCTCATT-1                 normal
# Name: disease, Length: 748679, dtype: category
# Categories (2, object): ['myeloid leukemia', 'normal']

# %%
# if filtering for disease
disease = 'myeloid leukemia'
full = full[full.obs['disease'] == disease]
dataset_name = 'aml'

# %%
# if filtering for normal
full = full[full.obs['disease'] == 'normal']

# %%
# filter categories if needed
#full = full[full.obs['disease'] != 'normal']

# remove unknown cell types
#full = full[full.obs[cell_type].notna()]
#full = full[full.obs[cell_type] != 'unknown'] # remove unknown?

# %%
mc.ut.top_level(full)
mc.ut.set_name(full, dataset_name + '.full')
full.var_names = full.var.feature_name.tolist()

print(f'full: {full.n_obs} cells, {full.n_vars} genes')
# Out:
# /mnt/scratch1/miniconda3/envs/metacell_MA/lib/python3.14/site-packages/metacells/utilities/annotation.py:980: ImplicitModificationWarning: Trying to modify attribute `._uns` of view, initializing view as actual.
#   adata.uns["__name__"] = name
# full: 77782 cells, 26936 genes

# %%
# sum duplicates
mc.ut.sum_duplicates(full.X)

# %%
# excluding low and high umi cells
# just using these as default since most datasets already went through qc
PROPERLY_SAMPLED_MIN_CELL_TOTAL = 500
PROPERLY_SAMPLED_MAX_CELL_TOTAL = 20000

total_umis_per_cell = mc.ut.get_o_numpy(full, '__x__', sum=True)
plot = sb.displot(total_umis_per_cell, log_scale=(10, None))
plot.set(xlabel='UMIs', ylabel='Density', yticks=[])

plot.refline(x=PROPERLY_SAMPLED_MIN_CELL_TOTAL, color='darkgreen')
plot.refline(x=PROPERLY_SAMPLED_MAX_CELL_TOTAL, color='crimson')

plt.savefig(OUTPUT_DIR + 'figures/' + dataset_name + '_cell_total_umis.svg')

too_small_cells_count = np.sum(total_umis_per_cell < PROPERLY_SAMPLED_MIN_CELL_TOTAL)
too_large_cells_count = np.sum(total_umis_per_cell > PROPERLY_SAMPLED_MAX_CELL_TOTAL)

total_umis_per_cell = mc.ut.get_o_numpy(full, name='__x__', sum=True)
too_small_cells_percent = 100.0 * too_small_cells_count / full.n_obs
too_large_cells_percent = 100.0 * too_large_cells_count / full.n_vars

print(
    f'Will exclude {too_small_cells_count} ({too_small_cells_percent:.2f}%%) cells'
    f' with less than {PROPERLY_SAMPLED_MIN_CELL_TOTAL} UMIs'
)
print(
    f'Will exclude {too_large_cells_count} ({too_large_cells_percent:.2f}%%) cells'
    f' with more than {PROPERLY_SAMPLED_MAX_CELL_TOTAL} UMIs'
)
# Out:
# Will exclude 0 (0.00%%) cells with less than 500 UMIs
# Will exclude 0 (0.00%%) cells with more than 20000 UMIs

# %%
# excluding genes by name/pattern
mc.pl.exclude_genes(
    full,
    excluded_gene_names=EXCLUDED_GENE_NAMES, 
    excluded_gene_patterns=EXCLUDED_GENE_PATTERNS,
    random_seed=123456,
)
# Out:
# /mnt/scratch1/miniconda3/envs/metacell_MA/lib/python3.14/site-packages/anndata/_core/anndata.py:1798: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /mnt/scratch1/miniconda3/envs/metacell_MA/lib/python3.14/site-packages/anndata/_core/anndata.py:1798: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# set diabetes2.full.var[bursty_lonely_gene]: 0 true (0%) out of 26936 bools
# set diabetes2.full.var[properly_sampled_gene]: 25659 true (95.26%) out of 26936 bools
# set diabetes2.full.var[excluded_gene]: 1292 true (4.797%) out of 26936 bools

# %%
# exclude cells with too high umi for excluded genes (metacell set this at 25%, i'm using 10%)
PROPERLY_SAMPLED_MAX_EXCLUDED_GENES_FRACTION = 0.1

mc.tl.compute_excluded_gene_umis(full)

excluded_umis_fraction_regularization = 1e-3  # Avoid 0 values in log scale plot.
excluded_umis_per_cell = mc.ut.get_o_numpy(full, 'excluded_umis')
excluded_umis_fraction_per_cell = excluded_umis_per_cell / total_umis_per_cell

excluded_umis_fraction_per_cell += excluded_umis_fraction_regularization
plot = sb.displot(excluded_umis_fraction_per_cell, log_scale=(10, None))
excluded_umis_fraction_per_cell -= excluded_umis_fraction_regularization

plot.set(xlabel='Fraction of excluded gene UMIs', ylabel='Density', yticks=[])
plot.refline(x=PROPERLY_SAMPLED_MAX_EXCLUDED_GENES_FRACTION, color='crimson')

plt.savefig(OUTPUT_DIR + 'figures/' + dataset_name + '_cell_excluded_umis_fraction.svg')

too_excluded_cells_count = np.sum(
    excluded_umis_fraction_per_cell > PROPERLY_SAMPLED_MAX_EXCLUDED_GENES_FRACTION
)
too_excluded_cells_fraction = too_excluded_cells_count / len(total_umis_per_cell)

print(
    f'Will exclude {too_excluded_cells_count} ({100 * too_excluded_cells_fraction:.2f}%) cells'
    f' with more than {100 * PROPERLY_SAMPLED_MAX_EXCLUDED_GENES_FRACTION:.2f}% excluded gene UMIs'
)
# Out:
# set diabetes2.full.obs[excluded_umis]: 77782 float32s
# Will exclude 0 (0.00%) cells with more than 10.00% excluded gene UMIs

# %%
# exclude cells with high umis of excluded genes
# exclude doublet cells if you know them, there's tools for this if it becomes an issue
if full.obs.columns.str.contains('doublet').any():
    doublet_cells_mask = full.obs.filter(regex='doublet')
    doublet_cells_mask = mc.ut.to_numpy_vector(doublet_cells_mask)
    mc.ut.set_o_data(full, 'doublet_cell', doublet_cells_mask)

    mc.pl.exclude_cells(
    full,
    properly_sampled_min_cell_total=PROPERLY_SAMPLED_MIN_CELL_TOTAL,
    properly_sampled_max_cell_total=PROPERLY_SAMPLED_MAX_CELL_TOTAL,
    properly_sampled_max_excluded_genes_fraction=PROPERLY_SAMPLED_MAX_EXCLUDED_GENES_FRACTION,
    additional_cells_masks=['|doublet_cell']
    )
else:
    mc.pl.exclude_cells(
        full,
        properly_sampled_min_cell_total=PROPERLY_SAMPLED_MIN_CELL_TOTAL,
        properly_sampled_max_cell_total=PROPERLY_SAMPLED_MAX_CELL_TOTAL,
        properly_sampled_max_excluded_genes_fraction=PROPERLY_SAMPLED_MAX_EXCLUDED_GENES_FRACTION
    )
# Out:
# set diabetes2.full.obs[properly_sampled_cell]: 77782 true (100%) out of 77782 bools
# set diabetes2.full.obs[excluded_cell]: 0 true (0%) out of 77782 bools

# %%
mc.pl.exclude_cells(
        full,
        properly_sampled_min_cell_total=PROPERLY_SAMPLED_MIN_CELL_TOTAL,
        properly_sampled_max_cell_total=PROPERLY_SAMPLED_MAX_CELL_TOTAL,
        properly_sampled_max_excluded_genes_fraction=PROPERLY_SAMPLED_MAX_EXCLUDED_GENES_FRACTION
    )
# Out:
# set bm.full.obs[properly_sampled_cell]: 162331 true (97.34%) out of 166765 bools
# set bm.full.obs[excluded_cell]: 4434 true (2.659%) out of 166765 bools

# %%
# extract clean data
clean = mc.pl.extract_clean_data(full, name=dataset_name + '.clean')
mc.ut.top_level(clean)
print(f'Clean: {clean.n_obs} cells, {clean.n_vars} genes')
# Out:
# /mnt/scratch1/miniconda3/envs/metacell_MA/lib/python3.14/site-packages/anndata/_core/anndata.py:1798: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# set diabetes2.clean.obs[full_cell_index]: 77782 int32s
# set diabetes2.clean.var[full_gene_index]: 25644 int32s
# Clean: 77782 cells, 25644 genes

# %%
# filter to necessary obs columns 
clean.obs = clean.obs[['cell_type']]
clean
# Out:
# AnnData object with n_obs × n_vars = 77782 × 25644
#     obs: 'cell_type'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'bursty_lonely_gene', 'properly_sampled_gene', 'excluded_gene', 'full_gene_index'
#     uns: 'batch_condition', 'cell_type_ontology_term_id_colors', 'citation', 'organism', 'organism_ontology_term_id', 'schema_reference', 'schema_version', 'title', '__name__'
#     obsm: 'X_umap'

# %%
# write clean data to output
clean.write_h5ad(OUTPUT_DIR + dataset_name + '.clean.h5ad')

# %%
clean = ad.read_h5ad(OUTPUT_DIR + dataset_name + '.clean.h5ad')
clean
# Out:
# /mnt/scratch1/miniconda3/envs/metacell_MA/lib/python3.14/site-packages/anndata/_core/anndata.py:1798: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 244461 × 22550
#     obs: 'cell_type', 'excluded_umis', 'properly_sampled_cell', 'excluded_cell', 'full_cell_index'
#     var: 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'bursty_lonely_gene', 'properly_sampled_gene', 'excluded_gene', 'full_gene_index'
#     uns: '__name__', 'citation', 'default_embedding', 'organism', 'organism_ontology_term_id', 'schema_reference', 'schema_version', 'title'
#     obsm: 'LVG_embedding', 'X_umap', 'cluster_memberships', 'embedding', 'precluster_denoised', 'precluster_embedding'

# %%
# for datasets being read by BPCells
meta = clean.obs[['cell_type']]
meta.to_csv(OUTPUT_DIR + dataset_name + '_metadata.csv', index=True)

# %%
adata = ad.read_h5ad('lymph_metacells/with_lateral/lymph_110.metacells.h5ad')
adata
# Out:
# /mnt/scratch1/miniconda3/envs/metacell_MA/lib/python3.14/site-packages/anndata/_core/anndata.py:1798: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# AnnData object with n_obs × n_vars = 2496 × 29494
#     obs: 'grouped', 'total_umis', '__zeros_downsample_umis', 'metacells_rare_gene_module', 'rare_metacell', 'cell_type', 'cell_type_fraction_of_CD14-low, CD16-positive monocyte', 'cell_type_fraction_of_CD14-positive, CD16-low monocyte', 'cell_type_fraction_of_CD16-negative, CD56-bright natural killer cell, human', 'cell_type_fraction_of_CD16-positive, CD56-dim natural killer cell, human', 'cell_type_fraction_of_CD4-positive, CD25-positive, alpha-beta regulatory T cell', 'cell_type_fraction_of_CD4-positive, alpha-beta memory T cell, CD45RO-positive', 'cell_type_fraction_of_T follicular helper cell', 'cell_type_fraction_of_class switched memory B cell', 'cell_type_fraction_of_dendritic cell, human', 'cell_type_fraction_of_double negative memory B cell', 'cell_type_fraction_of_fibroblast', 'cell_type_fraction_of_gamma-delta T cell', 'cell_type_fraction_of_germinal center B cell', 'cell_type_fraction_of_granzyme K-associated CD8 T cell', 'cell_type_fraction_of_group 3 innate lymphoid cell, human', 'cell_type_fraction_of_lymph node macrophage', 'cell_type_fraction_of_macrophage', 'cell_type_fraction_of_marginal zone B cell of lymph node', 'cell_type_fraction_of_mast cell', 'cell_type_fraction_of_mucosal-associated invariant T cell', 'cell_type_fraction_of_naive B cell', 'cell_type_fraction_of_naive regulatory T cell', 'cell_type_fraction_of_naive thymus-derived CD4-positive, alpha-beta T cell', 'cell_type_fraction_of_naive thymus-derived CD8-positive, alpha-beta T cell', 'cell_type_fraction_of_plasma cell', 'cell_type_fraction_of_plasmacytoid dendritic cell, human', 'cell_type_fraction_of_transitional stage B cell', 'sample_treatment_summary', 'sample_treatment_summary_fraction_of_Quadrivalent Inactivated Influenza Vaccine', 'sample_treatment_summary_fraction_of_no treatment', 'metacell', 'metacell_fraction_of_-1', 'metacell_fraction_of_0', 'metacell_fraction_of_1', 'metacell_fraction_of_2', 'metacell_fraction_of_3', 'metacell_fraction_of_4', 'metacell_fraction_of_5', 'metacell_fraction_of_6', 'metacell_fraction_of_7', 'metacell_fraction_of_8', 'metacell_fraction_of_9', 'metacell_fraction_of_10', 'metacell_fraction_of_11', 'metacell_fraction_of_12', 'metacell_fraction_of_13', 'metacell_fraction_of_14', 'metacell_fraction_of_15', 'metacell_fraction_of_16', 'metacell_fraction_of_17', 'metacell_fraction_of_18', 'metacell_fraction_of_19', 'metacell_fraction_of_20', 'metacell_fraction_of_21', 'metacell_fraction_of_22', 'metacell_fraction_of_23', 'metacell_fraction_of_24', 'metacell_fraction_of_25', 'metacell_fraction_of_26', 'metacell_fraction_of_27', 'metacell_fraction_of_28', 'metacell_fraction_of_29', 'metacell_fraction_of_30', 'metacell_fraction_of_31', 'metacell_fraction_of_32', 'metacell_fraction_of_33', 'metacell_fraction_of_34', 'metacell_fraction_of_35', 'metacell_fraction_of_36', 'metacell_fraction_of_37', 'metacell_fraction_of_38', 'metacell_fraction_of_39', 'metacell_fraction_of_40', 'metacell_fraction_of_41', 'metacell_fraction_of_42', 'metacell_fraction_of_43', 'metacell_fraction_of_44', 'metacell_fraction_of_45', 'metacell_fraction_of_46', 'metacell_fraction_of_47', 'metacell_fraction_of_48', 'metacell_fraction_of_49', 'metacell_fraction_of_50', 'metacell_fraction_of_51', 'metacell_fraction_of_52', 'metacell_fraction_of_53', 'metacell_fraction_of_54', 'metacell_fraction_of_55', 'metacell_fraction_of_56', 'metacell_fraction_of_57', 'metacell_fraction_of_58', 'metacell_fraction_of_59', 'metacell_fraction_of_60', 'metacell_fraction_of_61', 'metacell_fraction_of_62', 'metacell_fraction_of_63', 'metacell_fraction_of_64', 'metacell_fraction_of_65', 'metacell_fraction_of_66', 'metacell_fraction_of_67', 'metacell_fraction_of_68', 'metacell_fraction_of_69', 'metacell_fraction_of_70', 'metacell_fraction_of_71', 'metacell_fraction_of_72', 'metacell_fraction_of_73', 'metacell_fraction_of_74', 'metacell_fraction_of_75', 'metacell_fraction_of_76', 'metacell_fraction_of_77', 'metacell_fraction_of_78', 'metacell_fraction_of_79', 'metacel ...
#     var: 'feature_is_filtered', 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'mean', 'std', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type', 'bursty_lonely_gene', 'properly_sampled_gene', 'excluded_gene', 'full_gene_index', 'lateral_gene', 'selected_gene', 'rare_gene', 'rare_gene_module', 'marker_gene', 'significant_inner_folds_count'
#     uns: '__name__', 'mcview_format', 'metacells_algorithm', 'outliers'
#     layers: 'inner_fold', 'inner_stdev_log', 'total_umis', 'zeros'
#     obsp: 'obs_balanced_ranks', 'obs_outgoing_weights', 'obs_pruned_ranks', 'umap_distances'
#     varp: 'var_similarity'
